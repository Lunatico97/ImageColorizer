# %%
from google.colab import drive ;
drive.mount('/content/drive') ;
# Out:
# Mounted at /content/drive

# %%
import os ;
import cv2 ;
import numpy as np ;
from os import listdir ;
import matplotlib.image as mpimg ;
import matplotlib.pyplot as plt ;
from skimage.color import rgb2lab, lab2rgb ;

# %%
sourceDirectory = "/content/drive/MyDrive/Celeb-A/img_align_celeba/images/" ;
num_images = 8000 ;
images = [] ;

# %%
# I tried to make a subdirectory extractor
for image in os.listdir(sourceDirectory):
    if(image.endswith(".jpg")):
        data = mpimg.imread(sourceDirectory + '/' + image) ;
        data = cv2.resize(data, (128,128)) ;
        images.append(data) ;
        if(len(images) >= num_images):
          break ;

# %%
images = np.array(images, dtype='float32')/255 ;
images.shape
# Out:
# (8000, 128, 128, 3)

# %%
from sklearn.model_selection import train_test_split ;
xtrain, xtest = train_test_split(images, test_size=1000) ;
del images ;

# %%
print('Training Images: ', xtrain.shape) ;
print('Testing Images: ', xtest.shape) ;
# Out:
# Training Images:  (7000, 128, 128, 3)
# Testing Images:  (1000, 128, 128, 3)

# %%
np.save('xtest.npy', xtest) ;
del xtest ;

# %%
import tensorflow as tf ;
from tensorflow.keras import layers, models ;
from tensorflow.keras.utils import plot_model ;

# %%
np.random.seed(123) ;
tf.random.set_seed(123) ;
device = tf.test.gpu_device_name() ;
device
# Out:
# '/device:GPU:0'

# %%
# Down sampler CNN network
def downCNN(name, filters, kernel_size, batchNormalization = True):
    downsampler = models.Sequential() ;
    downsampler._name = name ;
    downsampler.add(layers.Conv2D(filters, kernel_size, padding = 'same', strides = 2)) ;
    if batchNormalization: downsampler.add(layers.BatchNormalization()) ;
    downsampler.add(layers.LeakyReLU()) ;
    return downsampler ;

# %%
# Up sampler CNN network
def upCNN(name, filters, kernel_size, normalize=True, dropOut = True):
    upsampler = models.Sequential() ;
    upsampler._name = name ;
    upsampler.add(layers.Conv2DTranspose(filters, kernel_size, padding = 'same', strides = 2)) ;
    if normalize: upsampler.add(layers.BatchNormalization()) ;
    if dropOut: upsampler.add(layers.Dropout(0.2)) ;
    upsampler.add(layers.LeakyReLU()) ;
    return upsampler ;

# %%
downsampler = downCNN("Down-sampler", 128, (3,3), True) ;
upsampler = upCNN("Up-sampler", 128, (3,3), True, True) ;
downsampler.build(input_shape=(None,128,128,3)) ;
upsampler.build(input_shape=(None,64,64,3)) ;
plot_model(downsampler, to_file='downsampler128filters.png', show_shapes=True) ;
plot_model(upsampler, to_file="upsampler128filters.png", show_shapes=True) ;
del downsampler ;
del upsampler ;

# %%
def AutoEncoder():
    # Input grayscale images of dimensions 128*128
    image = layers.Input(shape = [128,128,3]) ;

    # Feed it to an encoder network for downsampling to a latent vector
    d1 = downCNN("Downsampler_1", 128,(3,3),True)(image) ;
    d2 = downCNN("Downsampler_2", 128,(3,3),True)(d1) ;
    d3 = downCNN("Downsampler_3", 256,(3,3),True)(d2) ;
    d4 = downCNN("Downsampler_4", 512,(3,3),True)(d3) ;
    d5 = downCNN("Downsampler_5", 512,(3,3),False)(d4) ;

    # Decode the latent space bottleneck to upscale into large image matrix
    u1 = upCNN("Upsampler_1", 512,(3,3),True,False)(d5) ;
    u2 = upCNN("Upsampler_2", 256,(3,3),True,False)(u1) ;
    u3 = upCNN("Upsampler_3", 128,(3,3),True,False)(u2) ;
    u4 = upCNN("Upsampler_4", 128,(3,3),True,False)(u3) ;
    u5 = upCNN("Upsampler_5", 3,(3,3),False,False)(u4) ;

    # Generate colored images with final convolution
    output = layers.Conv2D(3, (2,2), strides = 1, activation='sigmoid', padding = 'same')(u5) ;
    return models.Model(inputs=image, outputs=output) ;

# %%
denoiser = AutoEncoder() ;
plot_model(denoiser, to_file='denoiserUsingAutoEncoder128*128.png', show_shapes=True) ;
print(denoiser.summary()) ;
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  Downsampler_1 (Sequential)  (None, 64, 64, 128)       4096
#
#  Downsampler_2 (Sequential)  (None, 32, 32, 128)       148096
#
#  Downsampler_3 (Sequential)  (None, 16, 16, 256)       296192
#
#  Downsampler_4 (Sequential)  (None, 8, 8, 512)         1182208
#
#  Downsampler_5 (Sequential)  (None, 4, 4, 512)         2359808
#
#  Upsampler_1 (Sequential)    (None, 8, 8, 512)         2361856
#
#  Upsampler_2 (Sequential)    (None, 16, 16, 256)       1180928
#
#  Upsampler_3 (Sequential)    (None, 32, 32, 128)       295552
#
#  Upsampler_4 (Sequential)    (None, 64, 64, 128)       148096
#
#  Upsampler_5 (Sequential)    (None, 128, 128, 3)       3459
#
#  conv2d_6 (Conv2D)           (None, 128, 128, 3)       39
#
# =================================================================
# Total params: 7980330 (30.44 MB)
# Trainable params: 7976234 (30.43 MB)
# Non-trainable params: 4096 (16.00 KB)
# _________________________________________________________________
# None

# %% [markdown]
# Dataset Analysis & Preprocessing

# %%
def showImage(data, index, label=None):
  plt.figure(figsize=(0.5, 0.5)) ;
  plt.imshow(data[index]) ;
  if label != None:
    plt.xlabel('Human') ;

# %%
figure, axes = plt.subplots(2, 3) ;
for i in range(6):
    axes[int(i/3)][int(i%3)].imshow(xtrain[i]) ;
    axes[int(i/3)][int(i%3)].set_xlabel('Human') ;
plt.show() ;

# %%
# Adding noise on the images
noise_factor = 0.15 ;
xtrainN = np.zeros((xtrain.shape[0],128,128,3)).astype(np.float32) ;
xtrainN = xtrain + noise_factor * np.random.normal(loc = 0.0 ,scale = 1.0, size = xtrain.shape) ;
xtrainN = np.clip(xtrainN, 0.0, 1.0) ;

# %%
figure, axes = plt.subplots(2, 3) ;
for i in range(6):
    axes[int(i/3)][int(i%3)].imshow(xtrainN[i]) ;
    axes[int(i/3)][int(i%3)].set_xlabel('Human') ;
plt.show() ;

# %% [markdown]
# Model Training & Evaluation

# %%
denoiser.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001), loss = 'mean_absolute_error', metrics = ['accuracy']) ;
denoiser

# %%
# !!! WARNING: This optimizes CPU performance - DON'T USE THIS WHEN GPU IS ENABLED !!! (Learnt the hard way!)
# tf.config.run_functions_eagerly(True) ; #  IT ENABLES CONVOLUTION LAYER TO FUNCTION EARLY CAUSING ISSUES IN TENSORS IF GPU IS USED
# tf.data.experimental.enable_debug_mode() ; # IT DISABLES PARALLELISM AND FORCES SEQUENTIAL OPERATION

# %%
history = denoiser.fit(xtrainN, xtrain, epochs = 200, batch_size = 50, validation_split=0.05, shuffle=True, verbose = True) ;
# Out:
# Epoch 1/200
# 133/133 [==============================] - 38s 144ms/step - loss: 0.0970 - accuracy: 0.7486 - val_loss: 0.1755 - val_accuracy: 0.7351
# Epoch 2/200
# 133/133 [==============================] - 18s 137ms/step - loss: 0.0612 - accuracy: 0.7855 - val_loss: 0.1427 - val_accuracy: 0.7410
# Epoch 3/200
# 133/133 [==============================] - 19s 140ms/step - loss: 0.0563 - accuracy: 0.7943 - val_loss: 0.0898 - val_accuracy: 0.7554
# Epoch 4/200
# 133/133 [==============================] - 19s 145ms/step - loss: 0.0517 - accuracy: 0.8072 - val_loss: 0.0560 - val_accuracy: 0.7778
# Epoch 5/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0502 - accuracy: 0.8158 - val_loss: 0.0564 - val_accuracy: 0.7821
# Epoch 6/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0477 - accuracy: 0.8205 - val_loss: 0.0616 - val_accuracy: 0.8151
# Epoch 7/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0469 - accuracy: 0.8254 - val_loss: 0.0601 - val_accuracy: 0.8028
# Epoch 8/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0458 - accuracy: 0.8287 - val_loss: 0.0686 - val_accuracy: 0.7268
# Epoch 9/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0449 - accuracy: 0.8352 - val_loss: 0.0615 - val_accuracy: 0.8045
# Epoch 10/200
# 133/133 [==============================] - 19s 140ms/step - loss: 0.0427 - accuracy: 0.8382 - val_loss: 0.0587 - val_accuracy: 0.7824
# Epoch 11/200
# 133/133 [==============================] - 19s 140ms/step - loss: 0.0418 - accuracy: 0.8449 - val_loss: 0.0605 - val_accuracy: 0.8010
# Epoch 12/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0415 - accuracy: 0.8449 - val_loss: 0.0584 - val_accuracy: 0.8150
# Epoch 13/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0405 - accuracy: 0.8473 - val_loss: 0.0517 - val_accuracy: 0.8249
# Epoch 14/200
# 133/133 [==============================] - 19s 140ms/step - loss: 0.0398 - accuracy: 0.8499 - val_loss: 0.0582 - val_accuracy: 0.8410
# Epoch 15/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0400 - accuracy: 0.8475 - val_loss: 0.0426 - val_accuracy: 0.8423
# Epoch 16/200
# 133/133 [==============================] - 19s 140ms/step - loss: 0.0398 - accuracy: 0.8468 - val_loss: 0.0559 - val_accuracy: 0.7966
# Epoch 17/200
# 133/133 [==============================] - 19s 140ms/step - loss: 0.0381 - accuracy: 0.8516 - val_loss: 0.0381 - val_accuracy: 0.8164
# Epoch 18/200
# 133/133 [==============================] - 19s 144ms/step - loss: 0.0379 - accuracy: 0.8512 - val_loss: 0.0445 - val_accuracy: 0.8110
# Epoch 19/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0372 - accuracy: 0.8507 - val_loss: 0.0679 - val_accuracy: 0.8089
# Epoch 20/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0384 - accuracy: 0.8509 - val_loss: 0.0434 - val_accuracy: 0.8294
# Epoch 21/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0379 - accuracy: 0.8538 - val_loss: 0.0424 - val_accuracy: 0.8323
# Epoch 22/200
# 133/133 [==============================] - 19s 140ms/step - loss: 0.0366 - accuracy: 0.8544 - val_loss: 0.0398 - val_accuracy: 0.8454
# Epoch 23/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0355 - accuracy: 0.8575 - val_loss: 0.0409 - val_accuracy: 0.8301
# Epoch 24/200
# 133/133 [==============================] - 19s 140ms/step - loss: 0.0370 - accuracy: 0.8539 - val_loss: 0.0359 - val_accuracy: 0.8376
# Epoch 25/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0350 - accuracy: 0.8557 - val_loss: 0.0418 - val_accuracy: 0.8298
# Epoch 26/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0349 - accuracy: 0.8553 - val_loss: 0.0427 - val_accuracy: 0.7924
# Epoch 27/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0341 - accuracy: 0.8560 - val_loss: 0.0365 - val_accuracy: 0.8321
# Epoch 28/200
# 133/133 [==============================] - 19s 140ms/step - loss: 0.0344 - accuracy: 0.8571 - val_loss: 0.0366 - val_accuracy: 0.8327
# Epoch 29/200
# 133/133 [==============================] - 19s 140ms/step - loss: 0.0346 - accuracy: 0.8559 - val_loss: 0.0410 - val_accuracy: 0.8625
# Epoch 30/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0337 - accuracy: 0.8577 - val_loss: 0.0379 - val_accuracy: 0.7781
# Epoch 31/200
# 133/133 [==============================] - 19s 140ms/step - loss: 0.0335 - accuracy: 0.8570 - val_loss: 0.0338 - val_accuracy: 0.8116
# Epoch 32/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0329 - accuracy: 0.8583 - val_loss: 0.0331 - val_accuracy: 0.8381
# Epoch 33/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0332 - accuracy: 0.8576 - val_loss: 0.0336 - val_accuracy: 0.8277
# Epoch 34/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0329 - accuracy: 0.8571 - val_loss: 0.0328 - val_accuracy: 0.8318
# Epoch 35/200
# 133/133 [==============================] - 19s 144ms/step - loss: 0.0328 - accuracy: 0.8566 - val_loss: 0.0337 - val_accuracy: 0.8032
# Epoch 36/200
# 133/133 [==============================] - 19s 140ms/step - loss: 0.0329 - accuracy: 0.8555 - val_loss: 0.0343 - val_accuracy: 0.8492
# Epoch 37/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0335 - accuracy: 0.8562 - val_loss: 0.0415 - val_accuracy: 0.8231
# Epoch 38/200
# 133/133 [==============================] - 19s 140ms/step - loss: 0.0324 - accuracy: 0.8576 - val_loss: 0.0316 - val_accuracy: 0.8638
# Epoch 39/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0324 - accuracy: 0.8586 - val_loss: 0.0344 - val_accuracy: 0.8468
# Epoch 40/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0330 - accuracy: 0.8553 - val_loss: 0.0349 - val_accuracy: 0.8012
# Epoch 41/200
# 133/133 [==============================] - 19s 140ms/step - loss: 0.0324 - accuracy: 0.8568 - val_loss: 0.0374 - val_accuracy: 0.8379
# Epoch 42/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0326 - accuracy: 0.8562 - val_loss: 0.0352 - val_accuracy: 0.8503
# Epoch 43/200
# 133/133 [==============================] - 19s 140ms/step - loss: 0.0319 - accuracy: 0.8578 - val_loss: 0.0358 - val_accuracy: 0.8308
# Epoch 44/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0315 - accuracy: 0.8591 - val_loss: 0.0325 - val_accuracy: 0.8412
# Epoch 45/200
# 133/133 [==============================] - 19s 140ms/step - loss: 0.0314 - accuracy: 0.8558 - val_loss: 0.0329 - val_accuracy: 0.8357
# Epoch 46/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0313 - accuracy: 0.8589 - val_loss: 0.0323 - val_accuracy: 0.8482
# Epoch 47/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0312 - accuracy: 0.8582 - val_loss: 0.0456 - val_accuracy: 0.8392
# Epoch 48/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0317 - accuracy: 0.8593 - val_loss: 0.0330 - val_accuracy: 0.8580
# Epoch 49/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0314 - accuracy: 0.8557 - val_loss: 0.0321 - val_accuracy: 0.8106
# Epoch 50/200
# 133/133 [==============================] - 19s 140ms/step - loss: 0.0310 - accuracy: 0.8601 - val_loss: 0.0315 - val_accuracy: 0.8297
# Epoch 51/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0309 - accuracy: 0.8587 - val_loss: 0.0331 - val_accuracy: 0.8043
# Epoch 52/200
# 133/133 [==============================] - 19s 140ms/step - loss: 0.0309 - accuracy: 0.8575 - val_loss: 0.0352 - val_accuracy: 0.8506
# Epoch 53/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0309 - accuracy: 0.8598 - val_loss: 0.0311 - val_accuracy: 0.8420
# Epoch 54/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0306 - accuracy: 0.8584 - val_loss: 0.0363 - val_accuracy: 0.8505
# Epoch 55/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0309 - accuracy: 0.8574 - val_loss: 0.0335 - val_accuracy: 0.8208
# Epoch 56/200
# 133/133 [==============================] - 19s 144ms/step - loss: 0.0306 - accuracy: 0.8596 - val_loss: 0.0413 - val_accuracy: 0.8276
# Epoch 57/200
# 133/133 [==============================] - 19s 140ms/step - loss: 0.0305 - accuracy: 0.8602 - val_loss: 0.0324 - val_accuracy: 0.8287
# Epoch 58/200
# 133/133 [==============================] - 19s 140ms/step - loss: 0.0302 - accuracy: 0.8611 - val_loss: 0.0318 - val_accuracy: 0.8464
# Epoch 59/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0303 - accuracy: 0.8583 - val_loss: 0.0308 - val_accuracy: 0.8203
# Epoch 60/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0304 - accuracy: 0.8589 - val_loss: 0.0355 - val_accuracy: 0.8254
# Epoch 61/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0299 - accuracy: 0.8625 - val_loss: 0.0323 - val_accuracy: 0.8556
# Epoch 62/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0307 - accuracy: 0.8608 - val_loss: 0.0341 - val_accuracy: 0.8042
# Epoch 63/200
# 133/133 [==============================] - 19s 140ms/step - loss: 0.0301 - accuracy: 0.8600 - val_loss: 0.0334 - val_accuracy: 0.8548
# Epoch 64/200
# 133/133 [==============================] - 19s 140ms/step - loss: 0.0302 - accuracy: 0.8621 - val_loss: 0.0318 - val_accuracy: 0.8404
# Epoch 65/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0297 - accuracy: 0.8602 - val_loss: 0.0312 - val_accuracy: 0.8476
# Epoch 66/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0301 - accuracy: 0.8609 - val_loss: 0.0386 - val_accuracy: 0.8473
# Epoch 67/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0297 - accuracy: 0.8616 - val_loss: 0.0348 - val_accuracy: 0.8306
# Epoch 68/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0297 - accuracy: 0.8589 - val_loss: 0.0303 - val_accuracy: 0.8356
# Epoch 69/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0295 - accuracy: 0.8605 - val_loss: 0.0335 - val_accuracy: 0.8362
# Epoch 70/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0299 - accuracy: 0.8629 - val_loss: 0.0333 - val_accuracy: 0.8492
# Epoch 71/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0296 - accuracy: 0.8607 - val_loss: 0.0331 - val_accuracy: 0.8216
# Epoch 72/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0301 - accuracy: 0.8607 - val_loss: 0.0311 - val_accuracy: 0.8330
# Epoch 73/200
# 133/133 [==============================] - 19s 140ms/step - loss: 0.0292 - accuracy: 0.8619 - val_loss: 0.0301 - val_accuracy: 0.8455
# Epoch 74/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0290 - accuracy: 0.8624 - val_loss: 0.0311 - val_accuracy: 0.8458
# Epoch 75/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0300 - accuracy: 0.8601 - val_loss: 0.0315 - val_accuracy: 0.8365
# Epoch 76/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0296 - accuracy: 0.8626 - val_loss: 0.0312 - val_accuracy: 0.8594
# Epoch 77/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0292 - accuracy: 0.8633 - val_loss: 0.0330 - val_accuracy: 0.8278
# Epoch 78/200
# 133/133 [==============================] - 19s 140ms/step - loss: 0.0289 - accuracy: 0.8636 - val_loss: 0.0314 - val_accuracy: 0.8478
# Epoch 79/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0295 - accuracy: 0.8611 - val_loss: 0.0444 - val_accuracy: 0.8147
# Epoch 80/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0292 - accuracy: 0.8623 - val_loss: 0.0311 - val_accuracy: 0.8414
# Epoch 81/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0291 - accuracy: 0.8593 - val_loss: 0.0303 - val_accuracy: 0.8425
# Epoch 82/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0288 - accuracy: 0.8639 - val_loss: 0.0314 - val_accuracy: 0.8358
# Epoch 83/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0290 - accuracy: 0.8624 - val_loss: 0.0307 - val_accuracy: 0.8295
# Epoch 84/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0286 - accuracy: 0.8657 - val_loss: 0.0296 - val_accuracy: 0.8412
# Epoch 85/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0285 - accuracy: 0.8630 - val_loss: 0.0320 - val_accuracy: 0.8460
# Epoch 86/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0289 - accuracy: 0.8652 - val_loss: 0.0386 - val_accuracy: 0.8213
# Epoch 87/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0287 - accuracy: 0.8640 - val_loss: 0.0312 - val_accuracy: 0.8224
# Epoch 88/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0283 - accuracy: 0.8643 - val_loss: 0.0307 - val_accuracy: 0.8418
# Epoch 89/200
# 133/133 [==============================] - 19s 145ms/step - loss: 0.0286 - accuracy: 0.8640 - val_loss: 0.0295 - val_accuracy: 0.8453
# Epoch 90/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0284 - accuracy: 0.8628 - val_loss: 0.0302 - val_accuracy: 0.8439
# Epoch 91/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0285 - accuracy: 0.8646 - val_loss: 0.0302 - val_accuracy: 0.8350
# Epoch 92/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0282 - accuracy: 0.8656 - val_loss: 0.0303 - val_accuracy: 0.8459
# Epoch 93/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0282 - accuracy: 0.8634 - val_loss: 0.0306 - val_accuracy: 0.8531
# Epoch 94/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0283 - accuracy: 0.8640 - val_loss: 0.0306 - val_accuracy: 0.8609
# Epoch 95/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0286 - accuracy: 0.8619 - val_loss: 0.0304 - val_accuracy: 0.8284
# Epoch 96/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0286 - accuracy: 0.8634 - val_loss: 0.0298 - val_accuracy: 0.8550
# Epoch 97/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0277 - accuracy: 0.8652 - val_loss: 0.0302 - val_accuracy: 0.8450
# Epoch 98/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0279 - accuracy: 0.8641 - val_loss: 0.0299 - val_accuracy: 0.8574
# Epoch 99/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0284 - accuracy: 0.8651 - val_loss: 0.0317 - val_accuracy: 0.8500
# Epoch 100/200
# 133/133 [==============================] - 19s 144ms/step - loss: 0.0283 - accuracy: 0.8645 - val_loss: 0.0304 - val_accuracy: 0.8181
# Epoch 101/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0281 - accuracy: 0.8665 - val_loss: 0.0310 - val_accuracy: 0.8386
# Epoch 102/200
# 133/133 [==============================] - 19s 144ms/step - loss: 0.0278 - accuracy: 0.8672 - val_loss: 0.0293 - val_accuracy: 0.8475
# Epoch 103/200
# 133/133 [==============================] - 19s 144ms/step - loss: 0.0279 - accuracy: 0.8661 - val_loss: 0.0297 - val_accuracy: 0.8340
# Epoch 104/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0275 - accuracy: 0.8657 - val_loss: 0.0294 - val_accuracy: 0.8402
# Epoch 105/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0278 - accuracy: 0.8658 - val_loss: 0.0306 - val_accuracy: 0.8508
# Epoch 106/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0275 - accuracy: 0.8670 - val_loss: 0.0302 - val_accuracy: 0.8187
# Epoch 107/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0279 - accuracy: 0.8669 - val_loss: 0.0319 - val_accuracy: 0.8465
# Epoch 108/200
# 133/133 [==============================] - 19s 144ms/step - loss: 0.0281 - accuracy: 0.8661 - val_loss: 0.0302 - val_accuracy: 0.8142
# Epoch 109/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0280 - accuracy: 0.8647 - val_loss: 0.0334 - val_accuracy: 0.8448
# Epoch 110/200
# 133/133 [==============================] - 19s 144ms/step - loss: 0.0278 - accuracy: 0.8658 - val_loss: 0.0301 - val_accuracy: 0.8282
# Epoch 111/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0275 - accuracy: 0.8676 - val_loss: 0.0298 - val_accuracy: 0.8673
# Epoch 112/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0279 - accuracy: 0.8655 - val_loss: 0.0314 - val_accuracy: 0.8431
# Epoch 113/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0278 - accuracy: 0.8660 - val_loss: 0.0302 - val_accuracy: 0.8168
# Epoch 114/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0276 - accuracy: 0.8667 - val_loss: 0.0313 - val_accuracy: 0.8621
# Epoch 115/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0278 - accuracy: 0.8664 - val_loss: 0.0299 - val_accuracy: 0.8298
# Epoch 116/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0274 - accuracy: 0.8670 - val_loss: 0.0309 - val_accuracy: 0.8398
# Epoch 117/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0275 - accuracy: 0.8684 - val_loss: 0.0310 - val_accuracy: 0.8161
# Epoch 118/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0273 - accuracy: 0.8668 - val_loss: 0.0300 - val_accuracy: 0.8643
# Epoch 119/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0272 - accuracy: 0.8672 - val_loss: 0.0304 - val_accuracy: 0.8481
# Epoch 120/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0274 - accuracy: 0.8689 - val_loss: 0.0294 - val_accuracy: 0.8717
# Epoch 121/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0271 - accuracy: 0.8683 - val_loss: 0.0305 - val_accuracy: 0.8373
# Epoch 122/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0273 - accuracy: 0.8666 - val_loss: 0.0305 - val_accuracy: 0.8276
# Epoch 123/200
# 133/133 [==============================] - 19s 144ms/step - loss: 0.0272 - accuracy: 0.8665 - val_loss: 0.0293 - val_accuracy: 0.8342
# Epoch 124/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0271 - accuracy: 0.8673 - val_loss: 0.0300 - val_accuracy: 0.8124
# Epoch 125/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0273 - accuracy: 0.8698 - val_loss: 0.0302 - val_accuracy: 0.8387
# Epoch 126/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0271 - accuracy: 0.8694 - val_loss: 0.0301 - val_accuracy: 0.8331
# Epoch 127/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0275 - accuracy: 0.8689 - val_loss: 0.0298 - val_accuracy: 0.8523
# Epoch 128/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0268 - accuracy: 0.8679 - val_loss: 0.0306 - val_accuracy: 0.8494
# Epoch 129/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0270 - accuracy: 0.8689 - val_loss: 0.0299 - val_accuracy: 0.8591
# Epoch 130/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0268 - accuracy: 0.8694 - val_loss: 0.0309 - val_accuracy: 0.8659
# Epoch 131/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0268 - accuracy: 0.8690 - val_loss: 0.0309 - val_accuracy: 0.8498
# Epoch 132/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0265 - accuracy: 0.8685 - val_loss: 0.0291 - val_accuracy: 0.8668
# Epoch 133/200
# 133/133 [==============================] - 19s 144ms/step - loss: 0.0268 - accuracy: 0.8691 - val_loss: 0.0329 - val_accuracy: 0.8373
# Epoch 134/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0272 - accuracy: 0.8679 - val_loss: 0.0302 - val_accuracy: 0.8269
# Epoch 135/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0271 - accuracy: 0.8668 - val_loss: 0.0306 - val_accuracy: 0.8667
# Epoch 136/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0274 - accuracy: 0.8672 - val_loss: 0.0367 - val_accuracy: 0.8259
# Epoch 137/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0270 - accuracy: 0.8700 - val_loss: 0.0293 - val_accuracy: 0.8545
# Epoch 138/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0271 - accuracy: 0.8701 - val_loss: 0.0301 - val_accuracy: 0.8383
# Epoch 139/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0265 - accuracy: 0.8705 - val_loss: 0.0305 - val_accuracy: 0.8580
# Epoch 140/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0266 - accuracy: 0.8683 - val_loss: 0.0295 - val_accuracy: 0.8364
# Epoch 141/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0269 - accuracy: 0.8688 - val_loss: 0.0298 - val_accuracy: 0.8489
# Epoch 142/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0265 - accuracy: 0.8701 - val_loss: 0.0308 - val_accuracy: 0.8426
# Epoch 143/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0267 - accuracy: 0.8683 - val_loss: 0.0331 - val_accuracy: 0.8425
# Epoch 144/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0267 - accuracy: 0.8677 - val_loss: 0.0309 - val_accuracy: 0.8503
# Epoch 145/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0265 - accuracy: 0.8685 - val_loss: 0.0303 - val_accuracy: 0.8279
# Epoch 146/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0264 - accuracy: 0.8702 - val_loss: 0.0320 - val_accuracy: 0.8616
# Epoch 147/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0266 - accuracy: 0.8686 - val_loss: 0.0297 - val_accuracy: 0.8494
# Epoch 148/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0264 - accuracy: 0.8688 - val_loss: 0.0320 - val_accuracy: 0.8297
# Epoch 149/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0269 - accuracy: 0.8702 - val_loss: 0.0294 - val_accuracy: 0.8306
# Epoch 150/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0264 - accuracy: 0.8707 - val_loss: 0.0290 - val_accuracy: 0.8436
# Epoch 151/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0266 - accuracy: 0.8689 - val_loss: 0.0293 - val_accuracy: 0.8374
# Epoch 152/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0262 - accuracy: 0.8708 - val_loss: 0.0297 - val_accuracy: 0.8365
# Epoch 153/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0264 - accuracy: 0.8700 - val_loss: 0.0292 - val_accuracy: 0.8505
# Epoch 154/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0261 - accuracy: 0.8687 - val_loss: 0.0308 - val_accuracy: 0.8529
# Epoch 155/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0263 - accuracy: 0.8709 - val_loss: 0.0317 - val_accuracy: 0.8652
# Epoch 156/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0262 - accuracy: 0.8715 - val_loss: 0.0293 - val_accuracy: 0.8460
# Epoch 157/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0261 - accuracy: 0.8716 - val_loss: 0.0298 - val_accuracy: 0.8520
# Epoch 158/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0266 - accuracy: 0.8679 - val_loss: 0.0288 - val_accuracy: 0.8613
# Epoch 159/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0264 - accuracy: 0.8705 - val_loss: 0.0302 - val_accuracy: 0.8636
# Epoch 160/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0266 - accuracy: 0.8684 - val_loss: 0.0318 - val_accuracy: 0.8324
# Epoch 161/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0262 - accuracy: 0.8702 - val_loss: 0.0296 - val_accuracy: 0.8592
# Epoch 162/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0260 - accuracy: 0.8712 - val_loss: 0.0304 - val_accuracy: 0.8655
# Epoch 163/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0263 - accuracy: 0.8704 - val_loss: 0.0305 - val_accuracy: 0.8384
# Epoch 164/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0261 - accuracy: 0.8716 - val_loss: 0.0294 - val_accuracy: 0.8440
# Epoch 165/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0257 - accuracy: 0.8717 - val_loss: 0.0305 - val_accuracy: 0.8332
# Epoch 166/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0261 - accuracy: 0.8716 - val_loss: 0.0306 - val_accuracy: 0.8305
# Epoch 167/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0259 - accuracy: 0.8716 - val_loss: 0.0295 - val_accuracy: 0.8656
# Epoch 168/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0259 - accuracy: 0.8717 - val_loss: 0.0296 - val_accuracy: 0.8308
# Epoch 169/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0263 - accuracy: 0.8693 - val_loss: 0.0291 - val_accuracy: 0.8479
# Epoch 170/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0259 - accuracy: 0.8691 - val_loss: 0.0287 - val_accuracy: 0.8532
# Epoch 171/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0260 - accuracy: 0.8720 - val_loss: 0.0293 - val_accuracy: 0.8490
# Epoch 172/200
# 133/133 [==============================] - 19s 140ms/step - loss: 0.0261 - accuracy: 0.8705 - val_loss: 0.0320 - val_accuracy: 0.8243
# Epoch 173/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0259 - accuracy: 0.8716 - val_loss: 0.0318 - val_accuracy: 0.8555
# Epoch 174/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0258 - accuracy: 0.8718 - val_loss: 0.0292 - val_accuracy: 0.8672
# Epoch 175/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0259 - accuracy: 0.8693 - val_loss: 0.0288 - val_accuracy: 0.8592
# Epoch 176/200
# 133/133 [==============================] - 19s 140ms/step - loss: 0.0258 - accuracy: 0.8720 - val_loss: 0.0288 - val_accuracy: 0.8413
# Epoch 177/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0259 - accuracy: 0.8722 - val_loss: 0.0288 - val_accuracy: 0.8521
# Epoch 178/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0260 - accuracy: 0.8712 - val_loss: 0.0292 - val_accuracy: 0.8737
# Epoch 179/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0255 - accuracy: 0.8738 - val_loss: 0.0284 - val_accuracy: 0.8721
# Epoch 180/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0258 - accuracy: 0.8722 - val_loss: 0.0320 - val_accuracy: 0.8542
# Epoch 181/200
# 133/133 [==============================] - 19s 144ms/step - loss: 0.0257 - accuracy: 0.8738 - val_loss: 0.0288 - val_accuracy: 0.8573
# Epoch 182/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0258 - accuracy: 0.8710 - val_loss: 0.0288 - val_accuracy: 0.8541
# Epoch 183/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0256 - accuracy: 0.8735 - val_loss: 0.0312 - val_accuracy: 0.8419
# Epoch 184/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0256 - accuracy: 0.8731 - val_loss: 0.0288 - val_accuracy: 0.8657
# Epoch 185/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0254 - accuracy: 0.8744 - val_loss: 0.0285 - val_accuracy: 0.8556
# Epoch 186/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0257 - accuracy: 0.8732 - val_loss: 0.0288 - val_accuracy: 0.8401
# Epoch 187/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0257 - accuracy: 0.8731 - val_loss: 0.0307 - val_accuracy: 0.8608
# Epoch 188/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0260 - accuracy: 0.8724 - val_loss: 0.0309 - val_accuracy: 0.8410
# Epoch 189/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0257 - accuracy: 0.8727 - val_loss: 0.0301 - val_accuracy: 0.8464
# Epoch 190/200
# 133/133 [==============================] - 19s 140ms/step - loss: 0.0256 - accuracy: 0.8719 - val_loss: 0.0296 - val_accuracy: 0.8447
# Epoch 191/200
# 133/133 [==============================] - 19s 140ms/step - loss: 0.0255 - accuracy: 0.8710 - val_loss: 0.0307 - val_accuracy: 0.8512
# Epoch 192/200
# 133/133 [==============================] - 19s 140ms/step - loss: 0.0255 - accuracy: 0.8729 - val_loss: 0.0303 - val_accuracy: 0.8499
# Epoch 193/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0253 - accuracy: 0.8725 - val_loss: 0.0294 - val_accuracy: 0.8413
# Epoch 194/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0254 - accuracy: 0.8739 - val_loss: 0.0290 - val_accuracy: 0.8243
# Epoch 195/200
# 133/133 [==============================] - 19s 140ms/step - loss: 0.0254 - accuracy: 0.8743 - val_loss: 0.0294 - val_accuracy: 0.8453
# Epoch 196/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0251 - accuracy: 0.8734 - val_loss: 0.0296 - val_accuracy: 0.8730
# Epoch 197/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0253 - accuracy: 0.8733 - val_loss: 0.0301 - val_accuracy: 0.8494
# Epoch 198/200
# 133/133 [==============================] - 19s 143ms/step - loss: 0.0252 - accuracy: 0.8722 - val_loss: 0.0288 - val_accuracy: 0.8578
# Epoch 199/200
# 133/133 [==============================] - 19s 141ms/step - loss: 0.0256 - accuracy: 0.8732 - val_loss: 0.0303 - val_accuracy: 0.8545
# Epoch 200/200
# 133/133 [==============================] - 19s 142ms/step - loss: 0.0253 - accuracy: 0.8729 - val_loss: 0.0287 - val_accuracy: 0.8672

# %%
figure, axes = plt.subplots(1,2, figsize=(12,4)) ;
axes[0].plot(history.history['accuracy'], label='Accuracy') ;
axes[0].plot(history.history['val_accuracy'], label='Validation Accuracy') ;
axes[0].set_xlabel('Epochs') ;
axes[0].set_ylabel('Accuracy') ;
axes[0].legend() ;
axes[1].plot(history.history['loss'], color='red', label='Model Loss') ;
axes[1].plot(history.history['val_loss'], color='blue', label='Validation Loss') ;
axes[1].set_xlabel('Epochs') ;
axes[1].set_ylabel('Loss: Mean Absolute Error (MAE)') ;
axes[1].legend() ;
plt.show() ;

# %%
# !pip install pyyaml h5py
denoiser.save('autoEncoderCNN_denoiser_celebs.h5') ;
denoiser.save('autoEncoderCNN_denoiser_celebs.keras') ;
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (6.0.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (3.9.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from h5py) (1.23.5)
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
del xtrain ;
xtest = np.load('xtest.npy') ;

# %%
xtestN = np.zeros((xtest.shape[0],128,128,3)).astype(np.float32) ;
xtestN = xtest + noise_factor * np.random.normal(loc = 0.0 ,scale = 1.0, size = xtestN.shape) ;
xtestN = np.clip(xtestN, 0.0, 1.0) ;

# %%
denoiser.evaluate(xtestN, xtest) ;
# Out:
# 32/32 [==============================] - 3s 47ms/step - loss: 0.0286 - accuracy: 0.8756

# %% [markdown]
# Model Prediction & Output Overview

# %%
showImage(xtest, 0) ;

# %%
showImage(xtestN, 0) ;

# %%
coloredOutput = denoiser.predict(xtestN[0].reshape(1,128,128,3)) ;
# Out:
# 1/1 [==============================] - 1s 604ms/step

# %%
coloredOutput = coloredOutput.astype(np.float32) ;
showImage(coloredOutput, 0) ;

# %%
randomIndex = np.random.randint(low=0, high=500, size=30) ;
for i in randomIndex:
  output = denoiser.predict(xtestN[i].reshape(1,128,128,3)) ;
  output = np.clip(output, 0.0, 1.0).astype(np.float32) ;
  figure, axes = plt.subplots(1,3, figsize=(6,1)) ;
  axes[0].imshow(xtest[i]) ;
  axes[1].imshow(xtestN[i], ) ;
  axes[1].set_xlabel('Human') ;
  axes[2].imshow(output[0]) ;
plt.show() ;
# Out:
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# <ipython-input-32-072be304bbbf>:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   figure, axes = plt.subplots(1,3, figsize=(6,1)) ;
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
